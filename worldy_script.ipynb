# %%
import pandas as pd

# Load the CSV file

df = pd.read_csv('stem_grid_2.csv')

# Display the first few rows to understand the structure
df.head()
# Out:
#   country  year  pct_female_stem  pct_male_stem  pct_female_in_NSMS  \
# 0     ABW  2000         8.166657      91.833343                 0.0
# 1     ABW  2001         6.056936      93.943064                 0.0
# 2     ABW  2002        14.398253      85.601747                 0.0
# 3     ABW  2003         3.942177      96.057823                 0.0
# 4     ABW  2004         7.210623      92.789377                 0.0
#
#    pct_female_in_ICT  pct_female_in_ECM  pct_male_in_NSMS  pct_male_in_ICT  \
# 0                0.0              100.0               0.0              0.0
# 1                0.0              100.0               0.0              0.0
# 2                0.0              100.0               0.0              0.0
# 3                0.0              100.0               0.0              0.0
# 4                0.0              100.0               0.0              0.0
#
#    pct_male_in_ECM country_name
# 0            100.0        Aruba
# 1            100.0        Aruba
# ...

# %%
df = df.drop(columns=['pct_male_stem', 'pct_male_in_NSMS','pct_male_in_ICT', 'pct_male_in_ECM'])
df.head(60)
# Out:
#    country  year  pct_female_stem  pct_female_in_NSMS  pct_female_in_ICT  \
# 0      ABW  2000         8.166657            0.000000           0.000000
# 1      ABW  2001         6.056936            0.000000           0.000000
# 2      ABW  2002        14.398253            0.000000           0.000000
# 3      ABW  2003         3.942177            0.000000           0.000000
# 4      ABW  2004         7.210623            0.000000           0.000000
# 5      ABW  2005         6.881487            0.000000           0.000000
# 6      ABW  2006         0.000000                 NaN                NaN
# 7      ABW  2007        13.235296            0.000000           0.000000
# 8      ABW  2008        10.060983            0.000000           0.000000
# 9      ABW  2009         7.820124            0.000000           0.000000
# 10     ABW  2010         3.856189            0.000000           0.000000
# 11     ABW  2011         9.752556            0.000000           0.000000
# ...

# %%
df.dropna(subset=['pct_female_stem'], inplace=True)
df.head(60)
# Out:
#     country  year  pct_female_stem  pct_female_in_NSMS  pct_female_in_ICT  \
# 0       ABW  2000         8.166657            0.000000           0.000000
# 1       ABW  2001         6.056936            0.000000           0.000000
# 2       ABW  2002        14.398253            0.000000           0.000000
# 3       ABW  2003         3.942177            0.000000           0.000000
# 4       ABW  2004         7.210623            0.000000           0.000000
# 5       ABW  2005         6.881487            0.000000           0.000000
# 6       ABW  2006         0.000000                 NaN                NaN
# 7       ABW  2007        13.235296            0.000000           0.000000
# 8       ABW  2008        10.060983            0.000000           0.000000
# 9       ABW  2009         7.820124            0.000000           0.000000
# 10      ABW  2010         3.856189            0.000000           0.000000
# 11      ABW  2011         9.752556            0.000000           0.000000
# ...

# %%
output_path = 'worldy.csv'
df.to_csv(output_path, index=False)
output_path
# Out:
# 'worldy.csv'
